# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import os

# %%
HOME = os.environ['HOME']

# %%
t2n3 = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t2n3/t2n3-times.xlsx'.format(HOME), sheet_name=None)
t4n7 = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t4n7/t4n7-times.xlsx'.format(HOME), sheet_name=None)
t5n9 = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t5n9/t5n9-times.xlsx'.format(HOME), sheet_name=None)
data = [t2n3, t4n7, t5n9]

# %%
mean_dict = dict()
std_dev_dict = dict()
conf_95_dict = dict()
for group in data:
    for key in group:
        mean_dict[key] = group[key]['elapsed'].mean()
        std_dev_dict[key] = group[key]['elapsed'].std()
        #conf_95_dict[key] = stats.norm.interval(0.95, loc=mean_dict[key], scale=std_dev_dict[key]/np.sqrt(len(data[key]['elapsed'])))
        interval = stats.t.interval(0.95, len(group[key]['elapsed'])-1, loc=mean_dict[key], scale=std_dev_dict[key]/np.sqrt(len(group[key]['elapsed'])))
        conf_95_dict[key] = (interval[1] - interval[0]) / 2

# %%
x = ['Threshold 2 - Shares 3', 'Threshold 4 - Shares 7', 'Threshold 5 - Shares 9']

split_5k_25 = [mean_dict['t2n3-5k-s-25'], mean_dict['t4n7-5k-s-25'], mean_dict['t5n9-5k-s-25']]
split_5k_50 = [mean_dict['t2n3-5k-s-50'], mean_dict['t4n7-5k-s-50'], mean_dict['t5n9-5k-s-50']]
split_5k_75 = [mean_dict['t2n3-5k-s-75'], mean_dict['t4n7-5k-s-75'], mean_dict['t5n9-5k-s-75']]
split_5k_100 = [mean_dict['t2n3-5k-s-100'], mean_dict['t4n7-5k-s-100'], mean_dict['t5n9-5k-s-100']]
split_5k_norm = [mean_dict['t2n3-5k-s-norm'], mean_dict['t4n7-5k-s-norm'], mean_dict['t5n9-5k-s-norm']]

split_10k_25 = [mean_dict['t2n3-10k-s-25'], mean_dict['t4n7-10k-s-25'], mean_dict['t5n9-10k-s-25']]
split_10k_50 = [mean_dict['t2n3-10k-s-50'], mean_dict['t4n7-10k-s-50'], mean_dict['t5n9-10k-s-50']]
split_10k_75 = [mean_dict['t2n3-10k-s-75'], mean_dict['t4n7-10k-s-75'], mean_dict['t5n9-10k-s-75']]
split_10k_100 = [mean_dict['t2n3-10k-s-100'], mean_dict['t4n7-10k-s-100'], mean_dict['t5n9-10k-s-100']]
split_10k_norm = [mean_dict['t2n3-10k-s-norm'], mean_dict['t4n7-10k-s-norm'], mean_dict['t5n9-10k-s-norm']]

split_15k_25 = [mean_dict['t2n3-15k-s-25'], mean_dict['t4n7-15k-s-25'], mean_dict['t5n9-15k-s-25']]
split_15k_50 = [mean_dict['t2n3-15k-s-50'], mean_dict['t4n7-15k-s-50'], mean_dict['t5n9-15k-s-50']]
split_15k_75 = [mean_dict['t2n3-15k-s-75'], mean_dict['t4n7-15k-s-75'], mean_dict['t5n9-15k-s-75']]
split_15k_100 = [mean_dict['t2n3-15k-s-100'], mean_dict['t4n7-15k-s-100'], mean_dict['t5n9-15k-s-100']]
split_15k_norm = [mean_dict['t2n3-15k-s-norm'], mean_dict['t4n7-15k-s-norm'], mean_dict['t5n9-15k-s-norm']]

split_20k_25 = [mean_dict['t2n3-20k-s-25'], mean_dict['t4n7-20k-s-25'], mean_dict['t5n9-20k-s-25']]
split_20k_50 = [mean_dict['t2n3-20k-s-50'], mean_dict['t4n7-20k-s-50'], mean_dict['t5n9-20k-s-50']]
split_20k_75 = [mean_dict['t2n3-20k-s-75'], mean_dict['t4n7-20k-s-75'], mean_dict['t5n9-20k-s-75']]
split_20k_100 = [mean_dict['t2n3-20k-s-100'], mean_dict['t4n7-20k-s-100'], mean_dict['t5n9-20k-s-100']]
split_20k_norm = [mean_dict['t2n3-20k-s-norm'], mean_dict['t4n7-20k-s-norm'], mean_dict['t5n9-20k-s-norm']]

split_25k_25 = [mean_dict['t2n3-25k-s-25'], mean_dict['t4n7-25k-s-25'], mean_dict['t5n9-25k-s-25']]
split_25k_50 = [mean_dict['t2n3-25k-s-50'], mean_dict['t4n7-25k-s-50'], mean_dict['t5n9-25k-s-50']]
split_25k_75 = [mean_dict['t2n3-25k-s-75'], mean_dict['t4n7-25k-s-75'], mean_dict['t5n9-25k-s-75']]
split_25k_100 = [mean_dict['t2n3-25k-s-100'], mean_dict['t4n7-25k-s-100'], mean_dict['t5n9-25k-s-100']]
split_25k_norm = [mean_dict['t2n3-25k-s-norm'], mean_dict['t4n7-25k-s-norm'], mean_dict['t5n9-25k-s-norm']]

split_30k_25 = [mean_dict['t2n3-30k-s-25'], mean_dict['t4n7-30k-s-25'], mean_dict['t5n9-30k-s-25']]
split_30k_50 = [mean_dict['t2n3-30k-s-50'], mean_dict['t4n7-30k-s-50'], mean_dict['t5n9-30k-s-50']]
split_30k_75 = [mean_dict['t2n3-30k-s-75'], mean_dict['t4n7-30k-s-75'], mean_dict['t5n9-30k-s-75']]
split_30k_100 = [mean_dict['t2n3-30k-s-100'], mean_dict['t4n7-30k-s-100'], mean_dict['t5n9-30k-s-100']]
split_30k_norm = [mean_dict['t2n3-30k-s-norm'], mean_dict['t4n7-30k-s-norm'], mean_dict['t5n9-30k-s-norm']]

retrieve_5k_25 = [mean_dict['t2n3-5k-r-25'], mean_dict['t4n7-5k-r-25'], mean_dict['t5n9-5k-r-25']]
retrieve_5k_50 = [mean_dict['t2n3-5k-r-50'], mean_dict['t4n7-5k-r-50'], mean_dict['t5n9-5k-r-50']]
retrieve_5k_75 = [mean_dict['t2n3-5k-r-75'], mean_dict['t4n7-5k-r-75'], mean_dict['t5n9-5k-r-75']]
retrieve_5k_100 = [mean_dict['t2n3-5k-r-100'], mean_dict['t4n7-5k-r-100'], mean_dict['t5n9-5k-r-100']]
retrieve_5k_norm = [mean_dict['t2n3-5k-r-norm'], mean_dict['t4n7-5k-r-norm'], mean_dict['t5n9-5k-r-norm']]

retrieve_10k_25 = [mean_dict['t2n3-10k-r-25'], mean_dict['t4n7-10k-r-25'], mean_dict['t5n9-10k-r-25']]
retrieve_10k_50 = [mean_dict['t2n3-10k-r-50'], mean_dict['t4n7-10k-r-50'], mean_dict['t5n9-10k-r-50']]
retrieve_10k_75 = [mean_dict['t2n3-10k-r-75'], mean_dict['t4n7-10k-r-75'], mean_dict['t5n9-10k-r-75']]
retrieve_10k_100 = [mean_dict['t2n3-10k-r-100'], mean_dict['t4n7-10k-r-100'], mean_dict['t5n9-10k-r-100']]
retrieve_10k_norm = [mean_dict['t2n3-10k-r-norm'], mean_dict['t4n7-10k-r-norm'], mean_dict['t5n9-10k-r-norm']]

retrieve_15k_25 = [mean_dict['t2n3-15k-r-25'], mean_dict['t4n7-15k-r-25'], mean_dict['t5n9-15k-r-25']]
retrieve_15k_50 = [mean_dict['t2n3-15k-r-50'], mean_dict['t4n7-15k-r-50'], mean_dict['t5n9-15k-r-50']]
retrieve_15k_75 = [mean_dict['t2n3-15k-r-75'], mean_dict['t4n7-15k-r-75'], mean_dict['t5n9-15k-r-75']]
retrieve_15k_100 = [mean_dict['t2n3-15k-r-100'], mean_dict['t4n7-15k-r-100'], mean_dict['t5n9-15k-r-100']]
retrieve_15k_norm = [mean_dict['t2n3-15k-r-norm'], mean_dict['t4n7-15k-r-norm'], mean_dict['t5n9-15k-r-norm']]

retrieve_20k_25 = [mean_dict['t2n3-20k-r-25'], mean_dict['t4n7-20k-r-25'], mean_dict['t5n9-20k-r-25']]
retrieve_20k_50 = [mean_dict['t2n3-20k-r-50'], mean_dict['t4n7-20k-r-50'], mean_dict['t5n9-20k-r-50']]
retrieve_20k_75 = [mean_dict['t2n3-20k-r-75'], mean_dict['t4n7-20k-r-75'], mean_dict['t5n9-20k-r-75']]
retrieve_20k_100 = [mean_dict['t2n3-20k-r-100'], mean_dict['t4n7-20k-r-100'], mean_dict['t5n9-20k-r-100']]
retrieve_20k_norm = [mean_dict['t2n3-20k-r-norm'], mean_dict['t4n7-20k-r-norm'], mean_dict['t5n9-20k-r-norm']]

retrieve_25k_25 = [mean_dict['t2n3-25k-r-25'], mean_dict['t4n7-25k-r-25'], mean_dict['t5n9-25k-r-25']]
retrieve_25k_50 = [mean_dict['t2n3-25k-r-50'], mean_dict['t4n7-25k-r-50'], mean_dict['t5n9-25k-r-50']]
retrieve_25k_75 = [mean_dict['t2n3-25k-r-75'], mean_dict['t4n7-25k-r-75'], mean_dict['t5n9-25k-r-75']]
retrieve_25k_100 = [mean_dict['t2n3-25k-r-100'], mean_dict['t4n7-25k-r-100'], mean_dict['t5n9-25k-r-100']]
retrieve_25k_norm = [mean_dict['t2n3-25k-r-norm'], mean_dict['t4n7-25k-r-norm'], mean_dict['t5n9-25k-r-norm']]

retrieve_30k_25 = [mean_dict['t2n3-30k-r-25'], mean_dict['t4n7-30k-r-25'], mean_dict['t5n9-30k-r-25']]
retrieve_30k_50 = [mean_dict['t2n3-30k-r-50'], mean_dict['t4n7-30k-r-50'], mean_dict['t5n9-30k-r-50']]
retrieve_30k_75 = [mean_dict['t2n3-30k-r-75'], mean_dict['t4n7-30k-r-75'], mean_dict['t5n9-30k-r-75']]
retrieve_30k_100 = [mean_dict['t2n3-30k-r-100'], mean_dict['t4n7-30k-r-100'], mean_dict['t5n9-30k-r-100']]
retrieve_30k_norm = [mean_dict['t2n3-30k-r-norm'], mean_dict['t4n7-30k-r-norm'], mean_dict['t5n9-30k-r-norm']]

split_5k_25_err = [conf_95_dict['t2n3-5k-s-25'], conf_95_dict['t4n7-5k-s-25'], conf_95_dict['t5n9-5k-s-25']]
split_5k_50_err = [conf_95_dict['t2n3-5k-s-50'], conf_95_dict['t4n7-5k-s-50'], conf_95_dict['t5n9-5k-s-50']]
split_5k_75_err = [conf_95_dict['t2n3-5k-s-75'], conf_95_dict['t4n7-5k-s-75'], conf_95_dict['t5n9-5k-s-75']]
split_5k_100_err = [conf_95_dict['t2n3-5k-s-100'], conf_95_dict['t4n7-5k-s-100'], conf_95_dict['t5n9-5k-s-100']]
split_5k_norm_err = [conf_95_dict['t2n3-5k-s-norm'], conf_95_dict['t4n7-5k-s-norm'], conf_95_dict['t5n9-5k-s-norm']]
split_10k_25_err = [conf_95_dict['t2n3-10k-s-25'], conf_95_dict['t4n7-10k-s-25'], conf_95_dict['t5n9-10k-s-25']]
split_10k_50_err = [conf_95_dict['t2n3-10k-s-50'], conf_95_dict['t4n7-10k-s-50'], conf_95_dict['t5n9-10k-s-50']]
split_10k_75_err = [conf_95_dict['t2n3-10k-s-75'], conf_95_dict['t4n7-10k-s-75'], conf_95_dict['t5n9-10k-s-75']]
split_10k_100_err = [conf_95_dict['t2n3-10k-s-100'], conf_95_dict['t4n7-10k-s-100'], conf_95_dict['t5n9-10k-s-100']]
split_10k_norm_err = [conf_95_dict['t2n3-10k-s-norm'], conf_95_dict['t4n7-10k-s-norm'], conf_95_dict['t5n9-10k-s-norm']]
split_15k_25_err = [conf_95_dict['t2n3-15k-s-25'], conf_95_dict['t4n7-15k-s-25'], conf_95_dict['t5n9-15k-s-25']]
split_15k_50_err = [conf_95_dict['t2n3-15k-s-50'], conf_95_dict['t4n7-15k-s-50'], conf_95_dict['t5n9-15k-s-50']]
split_15k_75_err = [conf_95_dict['t2n3-15k-s-75'], conf_95_dict['t4n7-15k-s-75'], conf_95_dict['t5n9-15k-s-75']]
split_15k_100_err = [conf_95_dict['t2n3-15k-s-100'], conf_95_dict['t4n7-15k-s-100'], conf_95_dict['t5n9-15k-s-100']]
split_15k_norm_err = [conf_95_dict['t2n3-15k-s-norm'], conf_95_dict['t4n7-15k-s-norm'], conf_95_dict['t5n9-15k-s-norm']]
split_20k_25_err = [conf_95_dict['t2n3-20k-s-25'], conf_95_dict['t4n7-20k-s-25'], conf_95_dict['t5n9-20k-s-25']]
split_20k_50_err = [conf_95_dict['t2n3-20k-s-50'], conf_95_dict['t4n7-20k-s-50'], conf_95_dict['t5n9-20k-s-50']]
split_20k_75_err = [conf_95_dict['t2n3-20k-s-75'], conf_95_dict['t4n7-20k-s-75'], conf_95_dict['t5n9-20k-s-75']]
split_20k_100_err = [conf_95_dict['t2n3-20k-s-100'], conf_95_dict['t4n7-20k-s-100'], conf_95_dict['t5n9-20k-s-100']]
split_20k_norm_err = [conf_95_dict['t2n3-20k-s-norm'], conf_95_dict['t4n7-20k-s-norm'], conf_95_dict['t5n9-20k-s-norm']]
split_25k_25_err = [conf_95_dict['t2n3-25k-s-25'], conf_95_dict['t4n7-25k-s-25'], conf_95_dict['t5n9-25k-s-25']]
split_25k_50_err = [conf_95_dict['t2n3-25k-s-50'], conf_95_dict['t4n7-25k-s-50'], conf_95_dict['t5n9-25k-s-50']]
split_25k_75_err = [conf_95_dict['t2n3-25k-s-75'], conf_95_dict['t4n7-25k-s-75'], conf_95_dict['t5n9-25k-s-75']]
split_25k_100_err = [conf_95_dict['t2n3-25k-s-100'], conf_95_dict['t4n7-25k-s-100'], conf_95_dict['t5n9-25k-s-100']]
split_25k_norm_err = [conf_95_dict['t2n3-25k-s-norm'], conf_95_dict['t4n7-25k-s-norm'], conf_95_dict['t5n9-25k-s-norm']]
split_30k_25_err = [conf_95_dict['t2n3-30k-s-25'], conf_95_dict['t4n7-30k-s-25'], conf_95_dict['t5n9-30k-s-25']]
split_30k_50_err = [conf_95_dict['t2n3-30k-s-50'], conf_95_dict['t4n7-30k-s-50'], conf_95_dict['t5n9-30k-s-50']]
split_30k_75_err = [conf_95_dict['t2n3-30k-s-75'], conf_95_dict['t4n7-30k-s-75'], conf_95_dict['t5n9-30k-s-75']]
split_30k_100_err = [conf_95_dict['t2n3-30k-s-100'], conf_95_dict['t4n7-30k-s-100'], conf_95_dict['t5n9-30k-s-100']]
split_30k_norm_err = [conf_95_dict['t2n3-30k-s-norm'], conf_95_dict['t4n7-30k-s-norm'], conf_95_dict['t5n9-30k-s-norm']]

retrieve_5k_25_err = [conf_95_dict['t2n3-5k-r-25'], conf_95_dict['t4n7-5k-r-25'], conf_95_dict['t5n9-5k-r-25']]
retrieve_5k_50_err = [conf_95_dict['t2n3-5k-r-50'], conf_95_dict['t4n7-5k-r-50'], conf_95_dict['t5n9-5k-r-50']]
retrieve_5k_75_err = [conf_95_dict['t2n3-5k-r-75'], conf_95_dict['t4n7-5k-r-75'], conf_95_dict['t5n9-5k-r-75']]
retrieve_5k_100_err = [conf_95_dict['t2n3-5k-r-100'], conf_95_dict['t4n7-5k-r-100'], conf_95_dict['t5n9-5k-r-100']]
retrieve_5k_norm_err = [conf_95_dict['t2n3-5k-r-norm'], conf_95_dict['t4n7-5k-r-norm'], conf_95_dict['t5n9-5k-r-norm']]
retrieve_10k_25_err = [conf_95_dict['t2n3-10k-r-25'], conf_95_dict['t4n7-10k-r-25'], conf_95_dict['t5n9-10k-r-25']]
retrieve_10k_50_err = [conf_95_dict['t2n3-10k-r-50'], conf_95_dict['t4n7-10k-r-50'], conf_95_dict['t5n9-10k-r-50']]
retrieve_10k_75_err = [conf_95_dict['t2n3-10k-r-75'], conf_95_dict['t4n7-10k-r-75'], conf_95_dict['t5n9-10k-r-75']]
retrieve_10k_100_err = [conf_95_dict['t2n3-10k-r-100'], conf_95_dict['t4n7-10k-r-100'], conf_95_dict['t5n9-10k-r-100']]
retrieve_10k_norm_err = [conf_95_dict['t2n3-10k-r-norm'], conf_95_dict['t4n7-10k-r-norm'], conf_95_dict['t5n9-10k-r-norm']]
retrieve_15k_25_err = [conf_95_dict['t2n3-15k-r-25'], conf_95_dict['t4n7-15k-r-25'], conf_95_dict['t5n9-15k-r-25']]
retrieve_15k_50_err = [conf_95_dict['t2n3-15k-r-50'], conf_95_dict['t4n7-15k-r-50'], conf_95_dict['t5n9-15k-r-50']]
retrieve_15k_75_err = [conf_95_dict['t2n3-15k-r-75'], conf_95_dict['t4n7-15k-r-75'], conf_95_dict['t5n9-15k-r-75']]
retrieve_15k_100_err = [conf_95_dict['t2n3-15k-r-100'], conf_95_dict['t4n7-15k-r-100'], conf_95_dict['t5n9-15k-r-100']]
retrieve_15k_norm_err = [conf_95_dict['t2n3-15k-r-norm'], conf_95_dict['t4n7-15k-r-norm'], conf_95_dict['t5n9-15k-r-norm']]
retrieve_20k_25_err = [conf_95_dict['t2n3-20k-r-25'], conf_95_dict['t4n7-20k-r-25'], conf_95_dict['t5n9-20k-r-25']]
retrieve_20k_50_err = [conf_95_dict['t2n3-20k-r-50'], conf_95_dict['t4n7-20k-r-50'], conf_95_dict['t5n9-20k-r-50']]
retrieve_20k_75_err = [conf_95_dict['t2n3-20k-r-75'], conf_95_dict['t4n7-20k-r-75'], conf_95_dict['t5n9-20k-r-75']]
retrieve_20k_100_err = [conf_95_dict['t2n3-20k-r-100'], conf_95_dict['t4n7-20k-r-100'], conf_95_dict['t5n9-20k-r-100']]
retrieve_20k_norm_err = [conf_95_dict['t2n3-20k-r-norm'], conf_95_dict['t4n7-20k-r-norm'], conf_95_dict['t5n9-20k-r-norm']]
retrieve_25k_25_err = [conf_95_dict['t2n3-25k-r-25'], conf_95_dict['t4n7-25k-r-25'], conf_95_dict['t5n9-25k-r-25']]
retrieve_25k_50_err = [conf_95_dict['t2n3-25k-r-50'], conf_95_dict['t4n7-25k-r-50'], conf_95_dict['t5n9-25k-r-50']]
retrieve_25k_75_err = [conf_95_dict['t2n3-25k-r-75'], conf_95_dict['t4n7-25k-r-75'], conf_95_dict['t5n9-25k-r-75']]
retrieve_25k_100_err = [conf_95_dict['t2n3-25k-r-100'], conf_95_dict['t4n7-25k-r-100'], conf_95_dict['t5n9-25k-r-100']]
retrieve_25k_norm_err = [conf_95_dict['t2n3-25k-r-norm'], conf_95_dict['t4n7-25k-r-norm'], conf_95_dict['t5n9-25k-r-norm']]
retrieve_30k_25_err = [conf_95_dict['t2n3-30k-r-25'], conf_95_dict['t4n7-30k-r-25'], conf_95_dict['t5n9-30k-r-25']]
retrieve_30k_50_err = [conf_95_dict['t2n3-30k-r-50'], conf_95_dict['t4n7-30k-r-50'], conf_95_dict['t5n9-30k-r-50']]
retrieve_30k_75_err = [conf_95_dict['t2n3-30k-r-75'], conf_95_dict['t4n7-30k-r-75'], conf_95_dict['t5n9-30k-r-75']]
retrieve_30k_100_err = [conf_95_dict['t2n3-30k-r-100'], conf_95_dict['t4n7-30k-r-100'], conf_95_dict['t5n9-30k-r-100']]
retrieve_30k_norm_err = [conf_95_dict['t2n3-30k-r-norm'], conf_95_dict['t4n7-30k-r-norm'], conf_95_dict['t5n9-30k-r-norm']]

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, split_10k_25, yerr=split_10k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, split_10k_50, yerr=split_10k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, split_10k_75, yerr=split_10k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, split_10k_100, yerr=split_10k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, split_10k_norm, yerr=split_10k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(split_10k_25):
    ax.text(i-0.3, v + 0.02, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_10k_50):
    ax.text(i-0.15, v + 0.02, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_10k_75):
    ax.text(i, v + 0.02, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_10k_100):
    ax.text(i+0.15, v + 0.02, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_10k_norm):
    ax.text(i+0.3, v + 0.02, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - 10kB Json')
ax.legend()

ax.set_ylim(0, 4.5)

plt.savefig('split-10k.png', dpi=300)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, retrieve_10k_25, yerr=retrieve_10k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, retrieve_10k_50, yerr=retrieve_10k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, retrieve_10k_75, yerr=retrieve_10k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, retrieve_10k_100, yerr=retrieve_10k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, retrieve_10k_norm, yerr=retrieve_10k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(retrieve_10k_25):
    ax.text(i-0.3, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_10k_50):
    ax.text(i-0.15, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_10k_75):
    ax.text(i, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_10k_100):
    ax.text(i+0.15, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_10k_norm):
    ax.text(i+0.3, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - 10kB Json')
ax.legend()

ax.set_ylim(0, 1.2)

plt.savefig('retrieve-10k.png', dpi=300)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, split_15k_25, yerr=split_15k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, split_15k_50, yerr=split_15k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, split_15k_75, yerr=split_15k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, split_15k_100, yerr=split_15k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, split_15k_norm, yerr=split_15k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(split_15k_25):
    ax.text(i-0.3, v + 0.04, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_15k_50):
    ax.text(i-0.15, v + 0.04, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_15k_75):
    ax.text(i, v + 0.04, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_15k_100):
    ax.text(i+0.15, v + 0.04, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_15k_norm):
    ax.text(i+0.3, v + 0.04, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - 15kB Json')
ax.legend()

ax.set_ylim(0, 4.5)

plt.savefig('split-15k.png', dpi=300)

plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, retrieve_15k_25, yerr=retrieve_15k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, retrieve_15k_50, yerr=retrieve_15k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, retrieve_15k_75, yerr=retrieve_15k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, retrieve_15k_100, yerr=retrieve_15k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, retrieve_15k_norm, yerr=retrieve_15k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(retrieve_15k_25):
    ax.text(i-0.3, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_15k_50):
    ax.text(i-0.15, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_15k_75):
    ax.text(i, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_15k_100):
    ax.text(i+0.15, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_15k_norm):
    ax.text(i+0.3, v + 0.01, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - 15kB Json')
ax.legend()

ax.set_ylim(0, 1.2)

plt.savefig('retrieve-15k.png', dpi=300)

plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, split_20k_25, yerr=split_20k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, split_20k_50, yerr=split_20k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, split_20k_75, yerr=split_20k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, split_20k_100, yerr=split_20k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, split_20k_norm, yerr=split_20k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(split_20k_25):
    ax.text(i-0.3, v + 0.06, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_20k_50):
    ax.text(i-0.15, v + 0.06, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_20k_75):
    ax.text(i, v + 0.06, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_20k_100):
    ax.text(i+0.15, v + 0.06, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_20k_norm):
    ax.text(i+0.3, v + 0.06, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - 20kB Json')
ax.legend()

ax.set_ylim(0, 4.5)

plt.savefig('split-20k.png', dpi=300)

plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, retrieve_20k_25, yerr=retrieve_20k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, retrieve_20k_50, yerr=retrieve_20k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, retrieve_20k_75, yerr=retrieve_20k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, retrieve_20k_100, yerr=retrieve_20k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, retrieve_20k_norm, yerr=retrieve_20k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(retrieve_20k_25):
    ax.text(i-0.3, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_20k_50):
    ax.text(i-0.15, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_20k_75):
    ax.text(i, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_20k_100):
    ax.text(i+0.15, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_20k_norm):
    ax.text(i+0.3, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - 20kB Json')
ax.legend()

ax.set_ylim(0, 1.2)

plt.savefig('retrieve-20k.png', dpi=300)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, split_25k_25, yerr=split_25k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, split_25k_50, yerr=split_25k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, split_25k_75, yerr=split_25k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, split_25k_100, yerr=split_25k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, split_25k_norm, yerr=split_25k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(split_25k_25):
    ax.text(i-0.3, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_25k_50):
    ax.text(i-0.15, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_25k_75):
    ax.text(i, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_25k_100):
    ax.text(i+0.15, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_25k_norm):
    ax.text(i+0.3, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - 25kB Json')
ax.legend()

ax.set_ylim(0, 4.5)

plt.savefig('split-25k.png', dpi=300)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, retrieve_25k_25, yerr=retrieve_25k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, retrieve_25k_50, yerr=retrieve_25k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, retrieve_25k_75, yerr=retrieve_25k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, retrieve_25k_100, yerr=retrieve_25k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, retrieve_25k_norm, yerr=retrieve_25k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(retrieve_25k_25):
    ax.text(i-0.3, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_25k_50):
    ax.text(i-0.15, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_25k_75):
    ax.text(i, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_25k_100):
    ax.text(i+0.15, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_25k_norm):
    ax.text(i+0.3, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - 25kB Json')
ax.legend()

ax.set_ylim(0, 1.2)

plt.savefig('retrieve-25k.png', dpi=300)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, split_30k_25, yerr=split_30k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, split_30k_50, yerr=split_30k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, split_30k_75, yerr=split_30k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, split_30k_100, yerr=split_30k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, split_30k_norm, yerr=split_30k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(split_30k_25):
    ax.text(i-0.3, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_30k_50):
    ax.text(i-0.15, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_30k_75):
    ax.text(i, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_30k_100):
    ax.text(i+0.15, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(split_30k_norm):
    ax.text(i+0.3, v + 0.08, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - 30kB Json')
ax.legend()

ax.set_ylim(0, 4.5)

plt.savefig('split-30k.png', dpi=300)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

ax.bar(positions - 0.225, retrieve_30k_25, yerr=retrieve_30k_25_err, capsize=5, width=0.15, label='Obfuscation 25%', hatch='//')
ax.bar(positions - 0.075, retrieve_30k_50, yerr=retrieve_30k_50_err, capsize=5, width=0.15, label='Obfuscation 50%', hatch='.')
ax.bar(positions + 0.075, retrieve_30k_75, yerr=retrieve_30k_75_err, capsize=5, width=0.15, label='Obfuscation 75%', hatch='x')
ax.bar(positions + 0.225, retrieve_30k_100, yerr=retrieve_30k_100_err, capsize=5, width=0.15, label='Obfuscation 100%', hatch='o')
ax.bar(positions + 0.375, retrieve_30k_norm, yerr=retrieve_30k_norm_err, capsize=5, width=0.15, label='Traditional approach', hatch='\\')

for i, v in enumerate(retrieve_30k_25):
    ax.text(i-0.3, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_30k_50):
    ax.text(i-0.15, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_30k_75):
    ax.text(i, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_30k_100):
    ax.text(i+0.15, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

for i, v in enumerate(retrieve_30k_norm):
    ax.text(i+0.3, v + 0.025, "{:.2f}".format(v), color='black', va='center', fontsize=7)

ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=8)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - 30kB Json')
ax.legend()

ax.set_ylim(0, 1.2)

plt.savefig('retrieve-30k.png', dpi=300)
plt.show()

# %% [markdown]
# GRAFICI AL VARIARE DELLA DIM

# %%
data = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t4n7/t4n7-times.xlsx'.format(HOME), sheet_name=None)

# %%
mean_dict = dict()
std_dev_dict = dict()
conf_95_dict = dict()
for key in data:
    mean_dict[key] = data[key]['elapsed'].mean()
    std_dev_dict[key] = data[key]['elapsed'].std()
    #conf_95_dict[key] = stats.norm.interval(0.95, loc=mean_dict[key], scale=std_dev_dict[key]/np.sqrt(len(data[key]['elapsed'])))
    interval = stats.t.interval(0.95, len(data[key]['elapsed'])-1, loc=mean_dict[key], scale=std_dev_dict[key]/np.sqrt(len(data[key]['elapsed'])))
    conf_95_dict[key] = (interval[1] - interval[0]) / 2

# %%
x = ['10kB','20kB', "30kB", "40kB", "50kB", "60kB", "70kB", "80kB", "90kB", "100kB"]
split25 = [mean_dict['t4n7-10k-s-25'], mean_dict['t4n7-20k-s-25'], mean_dict['t4n7-30k-s-25'], mean_dict['t4n7-40k-s-25'], mean_dict['t4n7-50k-s-25'], mean_dict['t4n7-60k-s-25'], mean_dict['t4n7-70k-s-25'], mean_dict['t4n7-80k-s-25'], mean_dict['t4n7-90k-s-25'], mean_dict['t4n7-100k-s-25']]
split50 = [mean_dict['t4n7-10k-s-50'], mean_dict['t4n7-20k-s-50'], mean_dict['t4n7-30k-s-50'], mean_dict['t4n7-40k-s-50'], mean_dict['t4n7-50k-s-50'], mean_dict['t4n7-60k-s-50'], mean_dict['t4n7-70k-s-50'], mean_dict['t4n7-80k-s-50'], mean_dict['t4n7-90k-s-50'], mean_dict['t4n7-100k-s-50']]
split75 = [mean_dict['t4n7-10k-s-75'], mean_dict['t4n7-20k-s-75'], mean_dict['t4n7-30k-s-75'], mean_dict['t4n7-40k-s-75'], mean_dict['t4n7-50k-s-75'], mean_dict['t4n7-60k-s-75'], mean_dict['t4n7-70k-s-75'], mean_dict['t4n7-80k-s-75'], mean_dict['t4n7-90k-s-75'], mean_dict['t4n7-100k-s-75']]
split100 = [mean_dict['t4n7-10k-s-100'], mean_dict['t4n7-20k-s-100'], mean_dict['t4n7-30k-s-100'], mean_dict['t4n7-40k-s-100'], mean_dict['t4n7-50k-s-100'], mean_dict['t4n7-60k-s-100'], mean_dict['t4n7-70k-s-100'], mean_dict['t4n7-80k-s-100'], mean_dict['t4n7-90k-s-100'], mean_dict['t4n7-100k-s-100']]
split_norm = [mean_dict['t4n7-10k-s-norm'], mean_dict['t4n7-20k-s-norm'], mean_dict['t4n7-30k-s-norm'], mean_dict['t4n7-40k-s-norm'], mean_dict['t4n7-50k-s-norm'], mean_dict['t4n7-60k-s-norm'], mean_dict['t4n7-70k-s-norm'], mean_dict['t4n7-80k-s-norm'], mean_dict['t4n7-90k-s-norm'], mean_dict['t4n7-100k-s-norm']]

retrieve25 = [mean_dict['t4n7-10k-r-25'], mean_dict['t4n7-20k-r-25'], mean_dict['t4n7-30k-r-25'], mean_dict['t4n7-40k-r-25'], mean_dict['t4n7-50k-r-25'], mean_dict['t4n7-60k-r-25'], mean_dict['t4n7-70k-r-25'], mean_dict['t4n7-80k-r-25'], mean_dict['t4n7-90k-r-25'], mean_dict['t4n7-100k-r-25']]
retrieve50 = [mean_dict['t4n7-10k-r-50'], mean_dict['t4n7-20k-r-50'], mean_dict['t4n7-30k-r-50'], mean_dict['t4n7-40k-r-50'], mean_dict['t4n7-50k-r-50'], mean_dict['t4n7-60k-r-50'], mean_dict['t4n7-70k-r-50'], mean_dict['t4n7-80k-r-50'], mean_dict['t4n7-90k-r-50'], mean_dict['t4n7-100k-r-50']]
retrieve75 = [mean_dict['t4n7-10k-r-75'], mean_dict['t4n7-20k-r-75'], mean_dict['t4n7-30k-r-75'], mean_dict['t4n7-40k-r-75'], mean_dict['t4n7-50k-r-75'], mean_dict['t4n7-60k-r-75'], mean_dict['t4n7-70k-r-75'], mean_dict['t4n7-80k-r-75'], mean_dict['t4n7-90k-r-75'], mean_dict['t4n7-100k-r-75']]
retrieve100 = [mean_dict['t4n7-10k-r-100'], mean_dict['t4n7-20k-r-100'], mean_dict['t4n7-30k-r-100'], mean_dict['t4n7-40k-r-100'], mean_dict['t4n7-50k-r-100'], mean_dict['t4n7-60k-r-100'], mean_dict['t4n7-70k-r-100'], mean_dict['t4n7-80k-r-100'], mean_dict['t4n7-90k-r-100'], mean_dict['t4n7-100k-r-100']]
retrieve_norm = [mean_dict['t4n7-10k-r-norm'], mean_dict['t4n7-20k-r-norm'], mean_dict['t4n7-30k-r-norm'], mean_dict['t4n7-40k-r-norm'], mean_dict['t4n7-50k-r-norm'], mean_dict['t4n7-60k-r-norm'], mean_dict['t4n7-70k-r-norm'], mean_dict['t4n7-80k-r-norm'], mean_dict['t4n7-90k-r-norm'], mean_dict['t4n7-100k-r-norm']]

split_error25 = [conf_95_dict['t4n7-10k-s-25'], conf_95_dict['t4n7-20k-s-25'], conf_95_dict['t4n7-30k-s-25'], conf_95_dict['t4n7-40k-s-25'], conf_95_dict['t4n7-50k-s-25'], conf_95_dict['t4n7-60k-s-25'], conf_95_dict['t4n7-70k-s-25'], conf_95_dict['t4n7-80k-s-25'], conf_95_dict['t4n7-90k-s-25'], conf_95_dict['t4n7-100k-s-25']]
split_error50 = [conf_95_dict['t4n7-10k-s-50'], conf_95_dict['t4n7-20k-s-50'], conf_95_dict['t4n7-30k-s-50'], conf_95_dict['t4n7-40k-s-50'], conf_95_dict['t4n7-50k-s-50'], conf_95_dict['t4n7-60k-s-50'], conf_95_dict['t4n7-70k-s-50'], conf_95_dict['t4n7-80k-s-50'], conf_95_dict['t4n7-90k-s-50'], conf_95_dict['t4n7-100k-s-50']]
split_error75 = [conf_95_dict['t4n7-10k-s-75'], conf_95_dict['t4n7-20k-s-75'], conf_95_dict['t4n7-30k-s-75'], conf_95_dict['t4n7-40k-s-75'], conf_95_dict['t4n7-50k-s-75'], conf_95_dict['t4n7-60k-s-75'], conf_95_dict['t4n7-70k-s-75'], conf_95_dict['t4n7-80k-s-75'], conf_95_dict['t4n7-90k-s-75'], conf_95_dict['t4n7-100k-s-75']]
split_error100 = [conf_95_dict['t4n7-10k-s-100'], conf_95_dict['t4n7-20k-s-100'], conf_95_dict['t4n7-30k-s-100'], conf_95_dict['t4n7-40k-s-100'], conf_95_dict['t4n7-50k-s-100'], conf_95_dict['t4n7-60k-s-100'], conf_95_dict['t4n7-70k-s-100'], conf_95_dict['t4n7-80k-s-100'], conf_95_dict['t4n7-90k-s-100'], conf_95_dict['t4n7-100k-s-100']]
split_error_norm = [conf_95_dict['t4n7-10k-s-norm'],  conf_95_dict['t4n7-20k-s-norm'], conf_95_dict['t4n7-30k-s-norm'], conf_95_dict['t4n7-40k-s-norm'], conf_95_dict['t4n7-50k-s-norm'], conf_95_dict['t4n7-60k-s-norm'], conf_95_dict['t4n7-70k-s-norm'], conf_95_dict['t4n7-80k-s-norm'], conf_95_dict['t4n7-90k-s-norm'], conf_95_dict['t4n7-100k-s-norm']]

retrieve_error25 = [conf_95_dict['t4n7-10k-r-25'], conf_95_dict['t4n7-20k-r-25'], conf_95_dict['t4n7-30k-r-25'], conf_95_dict['t4n7-40k-r-25'], conf_95_dict['t4n7-50k-r-25'], conf_95_dict['t4n7-60k-r-25'], conf_95_dict['t4n7-70k-r-25'], conf_95_dict['t4n7-80k-r-25'], conf_95_dict['t4n7-90k-r-25'], conf_95_dict['t4n7-100k-r-25']]
retrieve_error50 = [conf_95_dict['t4n7-10k-r-50'], conf_95_dict['t4n7-20k-r-50'], conf_95_dict['t4n7-30k-r-50'], conf_95_dict['t4n7-40k-r-50'], conf_95_dict['t4n7-50k-r-50'], conf_95_dict['t4n7-60k-r-50'], conf_95_dict['t4n7-70k-r-50'], conf_95_dict['t4n7-80k-r-50'], conf_95_dict['t4n7-90k-r-50'], conf_95_dict['t4n7-100k-r-50']]
retrieve_error75 = [conf_95_dict['t4n7-10k-r-75'], conf_95_dict['t4n7-20k-r-75'], conf_95_dict['t4n7-30k-r-75'], conf_95_dict['t4n7-40k-r-75'], conf_95_dict['t4n7-50k-r-75'], conf_95_dict['t4n7-60k-r-75'], conf_95_dict['t4n7-70k-r-75'], conf_95_dict['t4n7-80k-r-75'], conf_95_dict['t4n7-90k-r-75'], conf_95_dict['t4n7-100k-r-75']]
retrieve_error100 = [conf_95_dict['t4n7-10k-r-100'], conf_95_dict['t4n7-20k-r-100'], conf_95_dict['t4n7-30k-r-100'], conf_95_dict['t4n7-40k-r-100'], conf_95_dict['t4n7-50k-r-100'], conf_95_dict['t4n7-60k-r-100'], conf_95_dict['t4n7-70k-r-100'], conf_95_dict['t4n7-80k-r-100'], conf_95_dict['t4n7-90k-r-100'], conf_95_dict['t4n7-100k-r-100']]
retrieve_error_norm = [conf_95_dict['t4n7-10k-r-norm'], conf_95_dict['t4n7-20k-r-norm'], conf_95_dict['t4n7-30k-r-norm'], conf_95_dict['t4n7-40k-r-norm'], conf_95_dict['t4n7-50k-r-norm'], conf_95_dict['t4n7-60k-r-norm'], conf_95_dict['t4n7-70k-r-norm'], conf_95_dict['t4n7-80k-r-norm'], conf_95_dict['t4n7-90k-r-norm'], conf_95_dict['t4n7-100k-r-norm']]

# Posizioni delle barre sul grafico
positions = np.arange(len(x))

# Creazione del grafico
fig, ax = plt.subplots()

ax.plot(x, split25, label='Obfuscation 25%', linestyle='--', marker='.')
ax.plot(x, split50, label='Obfuscation 50%', linestyle='-.', marker='.')
ax.plot(x, split75, label='Obfuscation 75%', linestyle=':', marker='.')
ax.plot(x, split100, label='Obfuscation 100%', linestyle=(0, (3, 5, 1, 5, 1, 5)), marker='.')
ax.plot(x, split_norm, label='Traditional approach', linestyle='-', marker='.')

#Intervalli di confidenza
width = 1
length = 0.1

for i, (xi, yi, ci) in enumerate(zip(positions, split25, split_error25)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split50, split_error50)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split75, split_error75)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split100, split_error100)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split_norm, split_error_norm)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

# Aggiungi etichette ai valori
#for i, value in enumerate(split25):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split50):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split75):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split100):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split_norm):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)

# Etichette e titoli
ax.set_xticks(positions)
ax.set_xticklabels(x)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - Threshold 4 - Shares 7')
legend = ax.legend(handlelength=3)
for line in legend.get_lines():
    line.set_marker(marker='')

ax.set_ylim(0,17)

plt.savefig('split-t4n7.png', dpi=400)
# Mostra il grafico
plt.show()

# %%
# Posizioni delle barre sul grafico
positions = np.arange(len(x))

# Creazione del grafico
fig, ax = plt.subplots()

ax.plot(x, retrieve25, label='Obfuscation 25%', linestyle='--', marker='.')
ax.plot(x, retrieve50, label='Obfuscation 50%', linestyle='-.', marker='.')
ax.plot(x, retrieve75, label='Obfuscation 75%', linestyle=':', marker='.')
ax.plot(x, retrieve100, label='Obfuscation 100%', linestyle=(0, (3, 5, 1, 5, 1, 5)), marker='.')
ax.plot(x, retrieve_norm, label='Traditional approach', linestyle='-', marker='.')

#Intervalli di confidenza
width = 1
length = 0.1

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve25, retrieve_error25)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve50, retrieve_error50)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve75, retrieve_error75)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve100, retrieve_error100)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve_norm, retrieve_error_norm)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

# Aggiungi etichette ai valori
#for i, value in enumerate(split25):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split50):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split75):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split100):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split_norm):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)

# Etichette e titoli
ax.set_xticks(positions)
ax.set_xticklabels(x)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - Threshold 4 - Shares 7')
legend = ax.legend(handlelength=3)
for line in legend.get_lines():
    line.set_marker(marker='')

ax.set_ylim(0,4)

plt.savefig('retrieve-t4n7.png', dpi=400)
# Mostra il grafico
plt.show()

# %%
data = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t2n3/t2n3-times.xlsx'.format(HOME), sheet_name=None)

# %%
mean_dict = dict()
std_dev_dict = dict()
conf_95_dict = dict()
for key in data:
    mean_dict[key] = data[key]['elapsed'].mean()
    std_dev_dict[key] = data[key]['elapsed'].std()
    #conf_95_dict[key] = stats.norm.interval(0.95, loc=mean_dict[key], scale=std_dev_dict[key]/np.sqrt(len(data[key]['elapsed'])))
    interval = stats.t.interval(0.95, len(data[key]['elapsed'])-1, loc=mean_dict[key], scale=std_dev_dict[key]/np.sqrt(len(data[key]['elapsed'])))
    conf_95_dict[key] = (interval[1] - interval[0]) / 2

# %%
x = ['10kB', '20kB', "30kB", "40kB", "50kB", "60kB", "70kB", "80kB", "90kB", "100kB"]
split25 = [mean_dict['t2n3-10k-s-25'], mean_dict['t2n3-20k-s-25'], mean_dict['t2n3-30k-s-25'], mean_dict['t2n3-40k-s-25'], mean_dict['t2n3-50k-s-25'], mean_dict['t2n3-60k-s-25'], mean_dict['t2n3-70k-s-25'], mean_dict['t2n3-80k-s-25'], mean_dict['t2n3-90k-s-25'], mean_dict['t2n3-100k-s-25']]
split50 = [mean_dict['t2n3-10k-s-50'], mean_dict['t2n3-20k-s-50'], mean_dict['t2n3-30k-s-50'], mean_dict['t2n3-40k-s-50'], mean_dict['t2n3-50k-s-50'], mean_dict['t2n3-60k-s-50'], mean_dict['t2n3-70k-s-50'], mean_dict['t2n3-80k-s-50'], mean_dict['t2n3-90k-s-50'], mean_dict['t2n3-100k-s-50']]
split75 = [mean_dict['t2n3-10k-s-75'], mean_dict['t2n3-20k-s-75'], mean_dict['t2n3-30k-s-75'], mean_dict['t2n3-40k-s-75'], mean_dict['t2n3-50k-s-75'], mean_dict['t2n3-60k-s-75'], mean_dict['t2n3-70k-s-75'], mean_dict['t2n3-80k-s-75'], mean_dict['t2n3-90k-s-75'], mean_dict['t2n3-100k-s-75']]
split100 = [mean_dict['t2n3-10k-s-100'], mean_dict['t2n3-20k-s-100'], mean_dict['t2n3-30k-s-100'], mean_dict['t2n3-40k-s-100'], mean_dict['t2n3-50k-s-100'], mean_dict['t2n3-60k-s-100'], mean_dict['t2n3-70k-s-100'], mean_dict['t2n3-80k-s-100'], mean_dict['t2n3-90k-s-100'], mean_dict['t2n3-100k-s-100']]
split_norm = [mean_dict['t2n3-10k-s-norm'], mean_dict['t2n3-20k-s-norm'], mean_dict['t2n3-30k-s-norm'], mean_dict['t2n3-40k-s-norm'], mean_dict['t2n3-50k-s-norm'], mean_dict['t2n3-60k-s-norm'], mean_dict['t2n3-70k-s-norm'], mean_dict['t2n3-80k-s-norm'], mean_dict['t2n3-90k-s-norm'], mean_dict['t2n3-100k-s-norm']]
retrieve25 = [mean_dict['t2n3-10k-r-25'], mean_dict['t2n3-20k-r-25'], mean_dict['t2n3-30k-r-25'], mean_dict['t2n3-40k-r-25'], mean_dict['t2n3-50k-r-25'], mean_dict['t2n3-60k-r-25'], mean_dict['t2n3-70k-r-25'], mean_dict['t2n3-80k-r-25'], mean_dict['t2n3-90k-r-25'], mean_dict['t2n3-100k-r-25']]
retrieve50 = [mean_dict['t2n3-10k-r-50'], mean_dict['t2n3-20k-r-50'], mean_dict['t2n3-30k-r-50'], mean_dict['t2n3-40k-r-50'], mean_dict['t2n3-50k-r-50'], mean_dict['t2n3-60k-r-50'], mean_dict['t2n3-70k-r-50'], mean_dict['t2n3-80k-r-50'], mean_dict['t2n3-90k-r-50'], mean_dict['t2n3-100k-r-50']]
retrieve75 = [mean_dict['t2n3-10k-r-75'], mean_dict['t2n3-20k-r-75'], mean_dict['t2n3-30k-r-75'], mean_dict['t2n3-40k-r-75'], mean_dict['t2n3-50k-r-75'], mean_dict['t2n3-60k-r-75'], mean_dict['t2n3-70k-r-75'], mean_dict['t2n3-80k-r-75'], mean_dict['t2n3-90k-r-75'], mean_dict['t2n3-100k-r-75']]
retrieve100 = [mean_dict['t2n3-10k-r-100'], mean_dict['t2n3-20k-r-100'], mean_dict['t2n3-30k-r-100'], mean_dict['t2n3-40k-r-100'], mean_dict['t2n3-50k-r-100'], mean_dict['t2n3-60k-r-100'], mean_dict['t2n3-70k-r-100'], mean_dict['t2n3-80k-r-100'], mean_dict['t2n3-90k-r-100'], mean_dict['t2n3-100k-r-100']]
retrieve_norm = [mean_dict['t2n3-10k-r-norm'], mean_dict['t2n3-20k-r-norm'], mean_dict['t2n3-30k-r-norm'], mean_dict['t2n3-40k-r-norm'], mean_dict['t2n3-50k-r-norm'], mean_dict['t2n3-60k-r-norm'], mean_dict['t2n3-70k-r-norm'], mean_dict['t2n3-80k-r-norm'], mean_dict['t2n3-90k-r-norm'], mean_dict['t2n3-100k-r-norm']]
split_error25 = [conf_95_dict['t2n3-10k-s-25'], conf_95_dict['t2n3-20k-s-25'], conf_95_dict['t2n3-30k-s-25'], conf_95_dict['t2n3-40k-s-25'], conf_95_dict['t2n3-50k-s-25'], conf_95_dict['t2n3-60k-s-25'], conf_95_dict['t2n3-70k-s-25'], conf_95_dict['t2n3-80k-s-25'], conf_95_dict['t2n3-90k-s-25'], conf_95_dict['t2n3-100k-s-25']]
split_error50 = [conf_95_dict['t2n3-10k-s-50'], conf_95_dict['t2n3-20k-s-50'], conf_95_dict['t2n3-30k-s-50'], conf_95_dict['t2n3-40k-s-50'], conf_95_dict['t2n3-50k-s-50'], conf_95_dict['t2n3-60k-s-50'], conf_95_dict['t2n3-70k-s-50'], conf_95_dict['t2n3-80k-s-50'], conf_95_dict['t2n3-90k-s-50'], conf_95_dict['t2n3-100k-s-50']]
split_error75 = [conf_95_dict['t2n3-10k-s-75'], conf_95_dict['t2n3-20k-s-75'], conf_95_dict['t2n3-30k-s-75'], conf_95_dict['t2n3-40k-s-75'], conf_95_dict['t2n3-50k-s-75'], conf_95_dict['t2n3-60k-s-75'], conf_95_dict['t2n3-70k-s-75'], conf_95_dict['t2n3-80k-s-75'], conf_95_dict['t2n3-90k-s-75'], conf_95_dict['t2n3-100k-s-75']]
split_error100 = [conf_95_dict['t2n3-10k-s-100'], conf_95_dict['t2n3-20k-s-100'], conf_95_dict['t2n3-30k-s-100'], conf_95_dict['t2n3-40k-s-100'], conf_95_dict['t2n3-50k-s-100'], conf_95_dict['t2n3-60k-s-100'], conf_95_dict['t2n3-70k-s-100'], conf_95_dict['t2n3-80k-s-100'], conf_95_dict['t2n3-90k-s-100'], conf_95_dict['t2n3-100k-s-100']]
split_error_norm = [conf_95_dict['t2n3-10k-s-norm'], conf_95_dict['t2n3-20k-s-norm'], conf_95_dict['t2n3-30k-s-norm'], conf_95_dict['t2n3-40k-s-norm'], conf_95_dict['t2n3-50k-s-norm'], conf_95_dict['t2n3-60k-s-norm'], conf_95_dict['t2n3-70k-s-norm'], conf_95_dict['t2n3-80k-s-norm'], conf_95_dict['t2n3-90k-s-norm'], conf_95_dict['t2n3-100k-s-norm']]
retrieve_error25 = [conf_95_dict['t2n3-10k-r-25'], conf_95_dict['t2n3-20k-r-25'], conf_95_dict['t2n3-30k-r-25'], conf_95_dict['t2n3-40k-r-25'], conf_95_dict['t2n3-50k-r-25'], conf_95_dict['t2n3-60k-r-25'], conf_95_dict['t2n3-70k-r-25'], conf_95_dict['t2n3-80k-r-25'], conf_95_dict['t2n3-90k-r-25'], conf_95_dict['t2n3-100k-r-25']]
retrieve_error50 = [conf_95_dict['t2n3-10k-r-50'], conf_95_dict['t2n3-20k-r-50'], conf_95_dict['t2n3-30k-r-50'], conf_95_dict['t2n3-40k-r-50'], conf_95_dict['t2n3-50k-r-50'], conf_95_dict['t2n3-60k-r-50'], conf_95_dict['t2n3-70k-r-50'], conf_95_dict['t2n3-80k-r-50'], conf_95_dict['t2n3-90k-r-50'], conf_95_dict['t2n3-100k-r-50']]
retrieve_error75 = [conf_95_dict['t2n3-10k-r-75'], conf_95_dict['t2n3-20k-r-75'], conf_95_dict['t2n3-30k-r-75'], conf_95_dict['t2n3-40k-r-75'], conf_95_dict['t2n3-50k-r-75'], conf_95_dict['t2n3-60k-r-75'], conf_95_dict['t2n3-70k-r-75'], conf_95_dict['t2n3-80k-r-75'], conf_95_dict['t2n3-90k-r-75'], conf_95_dict['t2n3-100k-r-75']]
retrieve_error100 = [conf_95_dict['t2n3-10k-r-100'], conf_95_dict['t2n3-20k-r-100'], conf_95_dict['t2n3-30k-r-100'], conf_95_dict['t2n3-40k-r-100'], conf_95_dict['t2n3-50k-r-100'], conf_95_dict['t2n3-60k-r-100'], conf_95_dict['t2n3-70k-r-100'], conf_95_dict['t2n3-80k-r-100'], conf_95_dict['t2n3-90k-r-100'], conf_95_dict['t2n3-100k-r-100']]
retrieve_error_norm = [conf_95_dict['t2n3-10k-r-norm'], conf_95_dict['t2n3-20k-r-norm'], conf_95_dict['t2n3-30k-r-norm'], conf_95_dict['t2n3-40k-r-norm'], conf_95_dict['t2n3-50k-r-norm'], conf_95_dict['t2n3-60k-r-norm'], conf_95_dict['t2n3-70k-r-norm'], conf_95_dict['t2n3-80k-r-norm'], conf_95_dict['t2n3-90k-r-norm'], conf_95_dict['t2n3-100k-r-norm']]

# Posizioni delle barre sul grafico
positions = np.arange(len(x))

# Creazione del grafico
fig, ax = plt.subplots()

ax.plot(x, split25, label='Obfuscation 25%', linestyle='--', marker='.')
ax.plot(x, split50, label='Obfuscation 50%', linestyle='-.', marker='.')
ax.plot(x, split75, label='Obfuscation 75%', linestyle=':', marker='.')
ax.plot(x, split100, label='Obfuscation 100%', linestyle=(0, (3, 5, 1, 5, 1, 5)), marker='.')
ax.plot(x, split_norm, label='Traditional approach', linestyle='-', marker='.')

#Intervalli di confidenza
width = 1
length = 0.1

for i, (xi, yi, ci) in enumerate(zip(positions, split25, split_error25)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split50, split_error50)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split75, split_error75)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split100, split_error100)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split_norm, split_error_norm)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

# Aggiungi etichette ai valori
#for i, value in enumerate(split25):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split50):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split75):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split100):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split_norm):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)

# Etichette e titoli
ax.set_xticks(positions)
ax.set_xticklabels(x)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - Threshold 2 - Shares 3')
legend = ax.legend(handlelength=3)
for line in legend.get_lines():
    line.set_marker(marker='')

ax.set_ylim(0,17)

plt.savefig('split-t2n3.png', dpi=400)

# Mostra il grafico
plt.show()

# %%
# Posizioni delle barre sul grafico
positions = np.arange(len(x))

# Creazione del grafico
fig, ax = plt.subplots()

ax.plot(x, retrieve25, label='Obfuscation 25%', linestyle='--', marker='.')
ax.plot(x, retrieve50, label='Obfuscation 50%', linestyle='-.', marker='.')
ax.plot(x, retrieve75, label='Obfuscation 75%', linestyle=':', marker='.')
ax.plot(x, retrieve100, label='Obfuscation 100%', linestyle=(0, (3, 5, 1, 5, 1, 5)), marker='.')
ax.plot(x, retrieve_norm, label='Traditional approach', linestyle='-', marker='.')

#Intervalli di confidenza
width = 1
length = 0.1

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve25, retrieve_error25)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve50, retrieve_error50)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve75, retrieve_error75)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve100, retrieve_error100)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve_norm, retrieve_error_norm)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

# Aggiungi etichette ai valori
#for i, value in enumerate(split25):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split50):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split75):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split100):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split_norm):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)


# Etichette e titoli
ax.set_xticks(positions)
ax.set_xticklabels(x)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - Threshold 2 - Shares 3')
legend = ax.legend(handlelength=3)
for line in legend.get_lines():
    line.set_marker(marker='')

ax.set_ylim(0,4)

plt.savefig('retrieve-t2n3.png', dpi=400)

# Mostra il grafico
plt.show()

# %%
data = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t5n9/t5n9-times.xlsx'.format(HOME), sheet_name=None)

# %%
mean_dict = dict()
std_dev_dict = dict()
conf_95_dict = dict()
for key in data:
    mean_dict[key] = data[key]['elapsed'].mean()
    std_dev_dict[key] = data[key]['elapsed'].std()
    #conf_95_dict[key] = stats.norm.interval(0.95, loc=mean_dict[key], scale=std_dev_dict[key]/np.sqrt(len(data[key]['elapsed'])))
    interval = stats.t.interval(0.95, len(data[key]['elapsed'])-1, loc=mean_dict[key], scale=std_dev_dict[key]/np.sqrt(len(data[key]['elapsed'])))
    conf_95_dict[key] = (interval[1] - interval[0]) / 2

# %%
x = ['10kB', '20kB', "30kB", "40kB", "50kB", "60kB", "70kB", "80kB", "90kB", "100kB"]
split25 = [mean_dict['t5n9-10k-s-25'], mean_dict['t5n9-20k-s-25'], mean_dict['t5n9-30k-s-25'], mean_dict['t5n9-40k-s-25'], mean_dict['t5n9-50k-s-25'], mean_dict['t5n9-60k-s-25'], mean_dict['t5n9-70k-s-25'], mean_dict['t5n9-80k-s-25'], mean_dict['t5n9-90k-s-25'], mean_dict['t5n9-100k-s-25']]
split50 = [mean_dict['t5n9-10k-s-50'], mean_dict['t5n9-20k-s-50'], mean_dict['t5n9-30k-s-50'], mean_dict['t5n9-40k-s-50'], mean_dict['t5n9-50k-s-50'], mean_dict['t5n9-60k-s-50'], mean_dict['t5n9-70k-s-50'], mean_dict['t5n9-80k-s-50'], mean_dict['t5n9-90k-s-50'], mean_dict['t5n9-100k-s-50']]
split75 = [mean_dict['t5n9-10k-s-75'], mean_dict['t5n9-20k-s-75'], mean_dict['t5n9-30k-s-75'], mean_dict['t5n9-40k-s-75'], mean_dict['t5n9-50k-s-75'], mean_dict['t5n9-60k-s-75'], mean_dict['t5n9-70k-s-75'], mean_dict['t5n9-80k-s-75'], mean_dict['t5n9-90k-s-75'], mean_dict['t5n9-100k-s-75']]
split100 = [mean_dict['t5n9-10k-s-100'], mean_dict['t5n9-20k-s-100'], mean_dict['t5n9-30k-s-100'], mean_dict['t5n9-40k-s-100'], mean_dict['t5n9-50k-s-100'], mean_dict['t5n9-60k-s-100'], mean_dict['t5n9-70k-s-100'], mean_dict['t5n9-80k-s-100'], mean_dict['t5n9-90k-s-100'], mean_dict['t5n9-100k-s-100']]
split_norm = [mean_dict['t5n9-10k-s-norm'], mean_dict['t5n9-20k-s-norm'], mean_dict['t5n9-30k-s-norm'], mean_dict['t5n9-40k-s-norm'], mean_dict['t5n9-50k-s-norm'], mean_dict['t5n9-60k-s-norm'], mean_dict['t5n9-70k-s-norm'], mean_dict['t5n9-80k-s-norm'], mean_dict['t5n9-90k-s-norm'], mean_dict['t5n9-100k-s-norm']]
retrieve25 = [mean_dict['t5n9-10k-r-25'], mean_dict['t5n9-20k-r-25'], mean_dict['t5n9-30k-r-25'], mean_dict['t5n9-40k-r-25'], mean_dict['t5n9-50k-r-25'], mean_dict['t5n9-60k-r-25'], mean_dict['t5n9-70k-r-25'], mean_dict['t5n9-80k-r-25'], mean_dict['t5n9-90k-r-25'], mean_dict['t5n9-100k-r-25']]
retrieve50 = [mean_dict['t5n9-10k-r-50'], mean_dict['t5n9-20k-r-50'], mean_dict['t5n9-30k-r-50'], mean_dict['t5n9-40k-r-50'], mean_dict['t5n9-50k-r-50'], mean_dict['t5n9-60k-r-50'], mean_dict['t5n9-70k-r-50'], mean_dict['t5n9-80k-r-50'], mean_dict['t5n9-90k-r-50'], mean_dict['t5n9-100k-r-50']]
retrieve75 = [mean_dict['t5n9-10k-r-75'], mean_dict['t5n9-20k-r-75'], mean_dict['t5n9-30k-r-75'], mean_dict['t5n9-40k-r-75'], mean_dict['t5n9-50k-r-75'], mean_dict['t5n9-60k-r-75'], mean_dict['t5n9-70k-r-75'], mean_dict['t5n9-80k-r-75'], mean_dict['t5n9-90k-r-75'], mean_dict['t5n9-100k-r-75']]
retrieve100 = [mean_dict['t5n9-10k-r-100'], mean_dict['t5n9-20k-r-100'], mean_dict['t5n9-30k-r-100'], mean_dict['t5n9-40k-r-100'], mean_dict['t5n9-50k-r-100'], mean_dict['t5n9-60k-r-100'], mean_dict['t5n9-70k-r-100'], mean_dict['t5n9-80k-r-100'], mean_dict['t5n9-90k-r-100'], mean_dict['t5n9-100k-r-100']]
retrieve_norm = [mean_dict['t5n9-10k-r-norm'], mean_dict['t5n9-20k-r-norm'], mean_dict['t5n9-30k-r-norm'], mean_dict['t5n9-40k-r-norm'], mean_dict['t5n9-50k-r-norm'], mean_dict['t5n9-60k-r-norm'], mean_dict['t5n9-70k-r-norm'], mean_dict['t5n9-80k-r-norm'], mean_dict['t5n9-90k-r-norm'], mean_dict['t5n9-100k-r-norm']]
split_error25 = [conf_95_dict['t5n9-10k-s-25'], conf_95_dict['t5n9-20k-s-25'], conf_95_dict['t5n9-30k-s-25'], conf_95_dict['t5n9-40k-s-25'], conf_95_dict['t5n9-50k-s-25'], conf_95_dict['t5n9-60k-s-25'], conf_95_dict['t5n9-70k-s-25'], conf_95_dict['t5n9-80k-s-25'], conf_95_dict['t5n9-90k-s-25'], conf_95_dict['t5n9-100k-s-25']]
split_error50 = [conf_95_dict['t5n9-10k-s-50'], conf_95_dict['t5n9-20k-s-50'], conf_95_dict['t5n9-30k-s-50'], conf_95_dict['t5n9-40k-s-50'], conf_95_dict['t5n9-50k-s-50'], conf_95_dict['t5n9-60k-s-50'], conf_95_dict['t5n9-70k-s-50'], conf_95_dict['t5n9-80k-s-50'], conf_95_dict['t5n9-90k-s-50'], conf_95_dict['t5n9-100k-s-50']]
split_error75 = [conf_95_dict['t5n9-10k-s-75'], conf_95_dict['t5n9-20k-s-75'], conf_95_dict['t5n9-30k-s-75'], conf_95_dict['t5n9-40k-s-75'], conf_95_dict['t5n9-50k-s-75'], conf_95_dict['t5n9-60k-s-75'], conf_95_dict['t5n9-70k-s-75'], conf_95_dict['t5n9-80k-s-75'], conf_95_dict['t5n9-90k-s-75'], conf_95_dict['t5n9-100k-s-75']]
split_error100 = [conf_95_dict['t5n9-10k-s-100'], conf_95_dict['t5n9-20k-s-100'], conf_95_dict['t5n9-30k-s-100'], conf_95_dict['t5n9-40k-s-100'], conf_95_dict['t5n9-50k-s-100'], conf_95_dict['t5n9-60k-s-100'], conf_95_dict['t5n9-70k-s-100'], conf_95_dict['t5n9-80k-s-100'], conf_95_dict['t5n9-90k-s-100'], conf_95_dict['t5n9-100k-s-100']]
split_error_norm = [conf_95_dict['t5n9-10k-s-norm'], conf_95_dict['t5n9-20k-s-norm'], conf_95_dict['t5n9-30k-s-norm'], conf_95_dict['t5n9-40k-s-norm'], conf_95_dict['t5n9-50k-s-norm'], conf_95_dict['t5n9-60k-s-norm'], conf_95_dict['t5n9-70k-s-norm'], conf_95_dict['t5n9-80k-s-norm'], conf_95_dict['t5n9-90k-s-norm'], conf_95_dict['t5n9-100k-s-norm']]
retrieve_error25 = [conf_95_dict['t5n9-10k-r-25'], conf_95_dict['t5n9-20k-r-25'], conf_95_dict['t5n9-30k-r-25'], conf_95_dict['t5n9-40k-r-25'], conf_95_dict['t5n9-50k-r-25'], conf_95_dict['t5n9-60k-r-25'], conf_95_dict['t5n9-70k-r-25'], conf_95_dict['t5n9-80k-r-25'], conf_95_dict['t5n9-90k-r-25'], conf_95_dict['t5n9-100k-r-25']]
retrieve_error50 = [conf_95_dict['t5n9-10k-r-50'], conf_95_dict['t5n9-20k-r-50'], conf_95_dict['t5n9-30k-r-50'], conf_95_dict['t5n9-40k-r-50'], conf_95_dict['t5n9-50k-r-50'], conf_95_dict['t5n9-60k-r-50'], conf_95_dict['t5n9-70k-r-50'], conf_95_dict['t5n9-80k-r-50'], conf_95_dict['t5n9-90k-r-50'], conf_95_dict['t5n9-100k-r-50']]
retrieve_error75 = [conf_95_dict['t5n9-10k-r-75'], conf_95_dict['t5n9-20k-r-75'], conf_95_dict['t5n9-30k-r-75'], conf_95_dict['t5n9-40k-r-75'], conf_95_dict['t5n9-50k-r-75'], conf_95_dict['t5n9-60k-r-75'], conf_95_dict['t5n9-70k-r-75'], conf_95_dict['t5n9-80k-r-75'], conf_95_dict['t5n9-90k-r-75'], conf_95_dict['t5n9-100k-r-75']]
retrieve_error100 = [conf_95_dict['t5n9-10k-r-100'], conf_95_dict['t5n9-20k-r-100'], conf_95_dict['t5n9-30k-r-100'], conf_95_dict['t5n9-40k-r-100'], conf_95_dict['t5n9-50k-r-100'], conf_95_dict['t5n9-60k-r-100'], conf_95_dict['t5n9-70k-r-100'], conf_95_dict['t5n9-80k-r-100'], conf_95_dict['t5n9-90k-r-100'], conf_95_dict['t5n9-100k-r-100']]
retrieve_error_norm = [conf_95_dict['t5n9-10k-r-norm'], conf_95_dict['t5n9-20k-r-norm'], conf_95_dict['t5n9-30k-r-norm'], conf_95_dict['t5n9-40k-r-norm'], conf_95_dict['t5n9-50k-r-norm'], conf_95_dict['t5n9-60k-r-norm'], conf_95_dict['t5n9-70k-r-norm'], conf_95_dict['t5n9-80k-r-norm'], conf_95_dict['t5n9-90k-r-norm'], conf_95_dict['t5n9-100k-r-norm']]
# Posizioni delle barre sul grafico
positions = np.arange(len(x))

# Creazione del grafico
fig, ax = plt.subplots()

ax.plot(x, split25, label='Obfuscation 25%', linestyle='--', marker='.')
ax.plot(x, split50, label='Obfuscation 50%', linestyle='-.', marker='.')
ax.plot(x, split75, label='Obfuscation 75%', linestyle=':', marker='.')
ax.plot(x, split100, label='Obfuscation 100%', linestyle=(0, (3, 5, 1, 5, 1, 5)), marker='.')
ax.plot(x, split_norm, label='Traditional approach', linestyle='-', marker='.')

#Intervalli di confidenza
width = 1
length = 0.1

for i, (xi, yi, ci) in enumerate(zip(positions, split25, split_error25)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split50, split_error50)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split75, split_error75)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split100, split_error100)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, split_norm, split_error_norm)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

# Aggiungi etichette ai valori
#for i, value in enumerate(split25):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split50):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split75):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split100):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split_norm):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)


# Etichette e titoli
ax.set_xticks(positions)
ax.set_xticklabels(x)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - Threshold 5 - Shares 9')
legend = ax.legend(handlelength=3)
for line in legend.get_lines():
    line.set_marker(marker='')

ax.set_ylim(0,17)

plt.savefig('split-t5n9.png', dpi=400)


# Mostra il grafico
plt.show()

# %%
# Posizioni delle barre sul grafico
positions = np.arange(len(x))

# Creazione del grafico
fig, ax = plt.subplots()

ax.plot(x, retrieve25, label='Obfuscation 25%', linestyle='--', marker='.')
ax.plot(x, retrieve50, label='Obfuscation 50%', linestyle='-.', marker='.')
ax.plot(x, retrieve75, label='Obfuscation 75%', linestyle=':', marker='.')
ax.plot(x, retrieve100, label='Obfuscation 100%', linestyle=(0, (3, 5, 1, 5, 1, 5)), marker='.')
ax.plot(x, retrieve_norm, label='Traditional approach', linestyle='-', marker='.')

#Intervalli di confidenza
width = 1
length = 0.1

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve25, retrieve_error25)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve50, retrieve_error50)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve75, retrieve_error75)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve100, retrieve_error100)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

for i, (xi, yi, ci) in enumerate(zip(positions, retrieve_norm, retrieve_error_norm)):
    ax.plot([xi, xi], [yi - ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi + ci, yi + ci], color='black', linewidth=width)
    ax.plot([xi - length, xi + length], [yi - ci, yi - ci], color='black', linewidth=width)

# Aggiungi etichette ai valori
#for i, value in enumerate(split25):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split50):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split75):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split100):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)
#
#for i, value in enumerate(split_norm):
#    plt.text(positions[i], value + 0.01, str(round(value,2)), ha='center', va='bottom', fontsize=6)


# Etichette e titoli
ax.set_xticks(positions)
ax.set_xticklabels(x)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - Threshold 5 - Shares 9')
legend = ax.legend(handlelength=3)
for line in legend.get_lines():
    line.set_marker(marker='')

ax.set_ylim(0,4)

plt.savefig('retrieve-t5n9.png', dpi=400)

# Mostra il grafico
plt.show()

# %% [markdown]
# GRAFICI HL7

# %%
t2n3 = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t2n3/t2n3-times.xlsx'.format(HOME), sheet_name=None)
t3n5 = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t3n5/t3n5-times.xlsx'.format(HOME), sheet_name=None)
t4n7 = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t4n7/t4n7-times.xlsx'.format(HOME), sheet_name=None)
t5n9 = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t5n9/t5n9-times.xlsx'.format(HOME), sheet_name=None)
data = [t2n3, t3n5, t4n7, t5n9]
#data = pd.read_excel('{}/samothrace-pseudonymization/experiments-tools/csv-to-excel/times/t2n3/t2n3-times.xlsx'.format(HOME), sheet_name=None)

# %%
hl7_resources = ['Patient', 'Observation', 'Condition', 'Encounter', 'DiagnosticReport']

# %%
hl7_keys = []
for elem in data:
    for key in elem:
        for resource in hl7_resources:
            if resource in key:
                hl7_keys.append(key)

# %%
mean_dict = dict()
std_dev_dict = dict()
conf_95_dict = dict()
for group in data:
    for key in group:
        mean_dict[key] = group[key]['elapsed'].mean()
        std_dev_dict[key] = group[key]['elapsed'].std()
        interval = stats.t.interval(0.95, len(group[key]['elapsed'])-1, loc=mean_dict[key], scale=std_dev_dict[key]/np.sqrt(len(group[key]['elapsed'])))
        conf_95_dict[key] = (interval[1] - interval[0]) / 2

# %%
hatch_patterns = [
    '*',
    '+',
    '-',
    '.',
    '/',
    'O',
    'X',
    '\\',
    'o',
    'x',
    '|',
    '*/',
    '.\\'
    ]

# %%
patient_keys = []
observation_keys = []
condition_keys = []
encounter_keys = []
diagnostic_report_keys = []

for key in hl7_keys:
    if 'Patient' in key:
        patient_keys.append(key)
    elif 'Observation' in key:
        observation_keys.append(key)
    elif 'Condition' in key:
        condition_keys.append(key)
    elif 'Encounter' in key:
        encounter_keys.append(key)
    elif 'DiagnosticReport' in key:
        diagnostic_report_keys.append(key)

# %%
x = ['Threshold 2 - Shares 3', 'Threshold 3 - Shares 5', 'Threshold 4 - Shares 7', 'Threshold 5 - Shares 9']

percentages = []

for key in patient_keys:
    if '-s-' in key:
        percentage = key.split('-')[3]
        if percentage.isdigit():
            percentages.append(int(percentage))
        percentages.sort()
#percentages = [str(i) + '%' for i in percentages]
#percentages = [str(i) for i in percentages]
percentages = set(percentages)
percentages = sorted(list(percentages))
percentages = [str(i) for i in percentages]
percentages.append('norm')
percentages
# Out:
# ['4', '5', '10', '24', '26', '27', '31', '37', '57', '95', '98', '100', 'norm']

# %%
split = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}
split_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

for percentage in percentages:
    for key in patient_keys:
        if key.endswith('-' + percentage):
            if 't2n3' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t2n3]'.format(key))
                    split['t2n3'].append(mean_dict[key])
                    split_err['t2n3'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t2n3]'.format(key))
                    retrieve['t2n3'].append(mean_dict[key])
                    retrieve_err['t2n3'].append(conf_95_dict[key])
            elif 't3n5' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t3n5]'.format(key))
                    split['t3n5'].append(mean_dict[key])
                    split_err['t3n5'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t3n5]'.format(key))
                    retrieve['t3n5'].append(mean_dict[key])
                    retrieve_err['t3n5'].append(conf_95_dict[key])
            elif 't4n7' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t4n7]'.format(key))
                    split['t4n7'].append(mean_dict[key])
                    split_err['t4n7'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t4n7]'.format(key))
                    retrieve['t4n7'].append(mean_dict[key])
                    retrieve_err['t4n7'].append(conf_95_dict[key])
            elif 't5n9' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t5n9]'.format(key))
                    split['t5n9'].append(mean_dict[key])
                    split_err['t5n9'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t5n9]'.format(key))
                    retrieve['t5n9'].append(mean_dict[key])
                    retrieve_err['t5n9'].append(conf_95_dict[key])
# Out:
# appending key: t2n3-Patient-r-4 to retrieve[t2n3]
# appending key: t2n3-Patient-s-4 to split[t2n3]
# appending key: t3n5-Patient-r-4 to retrieve[t3n5]
# appending key: t3n5-Patient-s-4 to split[t3n5]
# appending key: t4n7-Patient-r-4 to retrieve[t4n7]
# appending key: t4n7-Patient-s-4 to split[t4n7]
# appending key: t5n9-Patient-r-4 to retrieve[t5n9]
# appending key: t5n9-Patient-s-4 to split[t5n9]
# appending key: t2n3-Patient-s-5 to split[t2n3]
# appending key: t2n3-Patient-r-5 to retrieve[t2n3]
# appending key: t3n5-Patient-s-5 to split[t3n5]
# appending key: t3n5-Patient-r-5 to retrieve[t3n5]
# appending key: t4n7-Patient-s-5 to split[t4n7]
# appending key: t4n7-Patient-r-5 to retrieve[t4n7]
# appending key: t5n9-Patient-s-5 to split[t5n9]
# appending key: t5n9-Patient-r-5 to retrieve[t5n9]
# appending key: t2n3-Patient-r-10 to retrieve[t2n3]
# appending key: t2n3-Patient-s-10 to split[t2n3]
# appending key: t3n5-Patient-r-10 to retrieve[t3n5]
# ...

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [split['t2n3'][i], split['t3n5'][i], split['t4n7'][i], split['t5n9'][i]],
            yerr=[split_err['t2n3'][i], split_err['t3n5'][i], split_err['t4n7'][i], split_err['t5n9'][i]],
            capsize=5,
            width=width,
            error_kw=dict(lw=1, capsize=2, capthick=1),
            label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
            hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - Patient')
ax.legend(
    handleheight=2,
    handlelength=3,
    fontsize=6,
)

plt.ylim(0, 0.1)
plt.savefig('split-patient.png', dpi=400)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [retrieve['t2n3'][i], retrieve['t3n5'][i], retrieve['t4n7'][i], retrieve['t5n9'][i]],
            yerr=[retrieve_err['t2n3'][i], retrieve_err['t3n5'][i], retrieve_err['t4n7'][i], retrieve_err['t5n9'][i]],
           capsize=5,
           width=width,
           error_kw=dict(lw=1, capsize=2, capthick=1),
           label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
           hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - Patient')
ax.legend(
    handleheight=2,
    handlelength=3,
    fontsize=6,
)

plt.ylim(0, 0.06)
plt.savefig('retrieve-patient.png', dpi=400)
plt.show()

# %%
x = ['Threshold 2 - Shares 3', 'Threshold 3 - Shares 5', 'Threshold 4 - Shares 7', 'Threshold 5 - Shares 9']

percentages = []

for key in observation_keys:
    if '-s-' in key:
        percentage = key.split('-')[3]
        if percentage.isdigit():
            percentages.append(int(percentage))
        percentages.sort()
#percentages = [str(i) + '%' for i in percentages]
#percentages = [str(i) for i in percentages]
percentages = set(percentages)
percentages = sorted(list(percentages))
percentages = [str(i) for i in percentages]
percentages.append('norm')
percentages
# Out:
# ['25', '31', '37', '43', '50', '75', '87', '93', '100', 'norm']

# %%
split = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}
split_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

for percentage in percentages:
    for key in observation_keys:
        if key.endswith('-' + percentage):
            if 't2n3' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t2n3]'.format(key))
                    split['t2n3'].append(mean_dict[key])
                    split_err['t2n3'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t2n3]'.format(key))
                    retrieve['t2n3'].append(mean_dict[key])
                    retrieve_err['t2n3'].append(conf_95_dict[key])
            elif 't3n5' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t3n5]'.format(key))
                    split['t3n5'].append(mean_dict[key])
                    split_err['t3n5'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t3n5]'.format(key))
                    retrieve['t3n5'].append(mean_dict[key])
                    retrieve_err['t3n5'].append(conf_95_dict[key])
            elif 't4n7' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t4n7]'.format(key))
                    split['t4n7'].append(mean_dict[key])
                    split_err['t4n7'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t4n7]'.format(key))
                    retrieve['t4n7'].append(mean_dict[key])
                    retrieve_err['t4n7'].append(conf_95_dict[key])
            elif 't5n9' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t5n9]'.format(key))
                    split['t5n9'].append(mean_dict[key])
                    split_err['t5n9'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t5n9]'.format(key))
                    retrieve['t5n9'].append(mean_dict[key])
                    retrieve_err['t5n9'].append(conf_95_dict[key])
# Out:
# appending key: t2n3-Observation-s-25 to split[t2n3]
# appending key: t2n3-Observation-r-25 to retrieve[t2n3]
# appending key: t3n5-Observation-s-25 to split[t3n5]
# appending key: t3n5-Observation-r-25 to retrieve[t3n5]
# appending key: t4n7-Observation-s-25 to split[t4n7]
# appending key: t4n7-Observation-r-25 to retrieve[t4n7]
# appending key: t5n9-Observation-s-25 to split[t5n9]
# appending key: t5n9-Observation-r-25 to retrieve[t5n9]
# appending key: t2n3-Observation-r-31 to retrieve[t2n3]
# appending key: t2n3-Observation-s-31 to split[t2n3]
# appending key: t3n5-Observation-r-31 to retrieve[t3n5]
# appending key: t3n5-Observation-s-31 to split[t3n5]
# appending key: t4n7-Observation-r-31 to retrieve[t4n7]
# appending key: t4n7-Observation-s-31 to split[t4n7]
# appending key: t5n9-Observation-r-31 to retrieve[t5n9]
# appending key: t5n9-Observation-s-31 to split[t5n9]
# appending key: t2n3-Observation-s-37 to split[t2n3]
# appending key: t2n3-Observation-r-37 to retrieve[t2n3]
# ...

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [split['t2n3'][i], split['t3n5'][i], split['t4n7'][i], split['t5n9'][i]],
            yerr=[split_err['t2n3'][i], split_err['t3n5'][i], split_err['t4n7'][i], split_err['t5n9'][i]],
           capsize=5,
           width=width,
           error_kw=dict(lw=1, capsize=2, capthick=1),
           label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
           hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - Observation')
ax.legend(
handleheight=2,     handlelength=3,     fontsize=6,
)

#plt.ylim(0, 0.1)

plt.savefig('split-observation.png', dpi=400)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [retrieve['t2n3'][i], retrieve['t3n5'][i], retrieve['t4n7'][i], retrieve['t5n9'][i]],
            yerr=[retrieve_err['t2n3'][i], retrieve_err['t3n5'][i], retrieve_err['t4n7'][i], retrieve_err['t5n9'][i]],
           capsize=5,
           width=width,
           error_kw=dict(lw=1, capsize=2, capthick=1),
           label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
           hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - Observation')
ax.legend(
handleheight=2,     handlelength=3,     fontsize=6,
)

#plt.ylim(0, 0.1)

plt.savefig('retrieve-observation.png', dpi=400)
plt.show()

# %%
x = ['Threshold 2 - Shares 3', 'Threshold 3 - Shares 5', 'Threshold 4 - Shares 7', 'Threshold 5 - Shares 9']

percentages = []

for key in diagnostic_report_keys:
    if '-s-' in key:
        percentage = key.split('-')[3]
        if percentage.isdigit():
            percentages.append(int(percentage))
        percentages.sort()
#percentages = [str(i) + '%' for i in percentages]
#percentages = [str(i) for i in percentages]
percentages = set(percentages)
percentages = sorted(list(percentages))
percentages = [str(i) for i in percentages]
percentages.append('norm')
percentages
# Out:
# ['64', '68', '72', '76', '80', '92', '96', '100', 'norm']

# %%
split = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}
split_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

for percentage in percentages:
    for key in diagnostic_report_keys:
        if key.endswith('-' + percentage):
            if 't2n3' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t2n3]'.format(key))
                    split['t2n3'].append(mean_dict[key])
                    split_err['t2n3'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t2n3]'.format(key))
                    retrieve['t2n3'].append(mean_dict[key])
                    retrieve_err['t2n3'].append(conf_95_dict[key])
            elif 't3n5' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t3n5]'.format(key))
                    split['t3n5'].append(mean_dict[key])
                    split_err['t3n5'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t3n5]'.format(key))
                    retrieve['t3n5'].append(mean_dict[key])
                    retrieve_err['t3n5'].append(conf_95_dict[key])
            elif 't4n7' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t4n7]'.format(key))
                    split['t4n7'].append(mean_dict[key])
                    split_err['t4n7'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t4n7]'.format(key))
                    retrieve['t4n7'].append(mean_dict[key])
                    retrieve_err['t4n7'].append(conf_95_dict[key])
            elif 't5n9' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t5n9]'.format(key))
                    split['t5n9'].append(mean_dict[key])
                    split_err['t5n9'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t5n9]'.format(key))
                    retrieve['t5n9'].append(mean_dict[key])
                    retrieve_err['t5n9'].append(conf_95_dict[key])
# Out:
# appending key: t2n3-DiagnosticReport-s-64 to split[t2n3]
# appending key: t2n3-DiagnosticReport-r-64 to retrieve[t2n3]
# appending key: t3n5-DiagnosticReport-s-64 to split[t3n5]
# appending key: t3n5-DiagnosticReport-r-64 to retrieve[t3n5]
# appending key: t4n7-DiagnosticReport-s-64 to split[t4n7]
# appending key: t4n7-DiagnosticReport-r-64 to retrieve[t4n7]
# appending key: t5n9-DiagnosticReport-s-64 to split[t5n9]
# appending key: t5n9-DiagnosticReport-r-64 to retrieve[t5n9]
# appending key: t2n3-DiagnosticReport-r-68 to retrieve[t2n3]
# appending key: t2n3-DiagnosticReport-s-68 to split[t2n3]
# appending key: t3n5-DiagnosticReport-r-68 to retrieve[t3n5]
# appending key: t3n5-DiagnosticReport-s-68 to split[t3n5]
# appending key: t4n7-DiagnosticReport-r-68 to retrieve[t4n7]
# appending key: t4n7-DiagnosticReport-s-68 to split[t4n7]
# appending key: t5n9-DiagnosticReport-r-68 to retrieve[t5n9]
# appending key: t5n9-DiagnosticReport-s-68 to split[t5n9]
# ...

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [split['t2n3'][i], split['t3n5'][i], split['t4n7'][i], split['t5n9'][i]],
            yerr=[split_err['t2n3'][i], split_err['t3n5'][i], split_err['t4n7'][i], split_err['t5n9'][i]],
           capsize=5,
           width=width,
           error_kw=dict(lw=1, capsize=2, capthick=1),
           label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
           hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - DiagnosticReport')
ax.legend(
handleheight=2,     handlelength=3,     fontsize=6,
)

#plt.ylim(0, 0.1)

plt.savefig('split-diagnostic-report.png', dpi=400)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [retrieve['t2n3'][i], retrieve['t3n5'][i], retrieve['t4n7'][i], retrieve['t5n9'][i]],
            yerr=[retrieve_err['t2n3'][i], retrieve_err['t3n5'][i], retrieve_err['t4n7'][i], retrieve_err['t5n9'][i]],
           capsize=5,
           width=width,
           error_kw=dict(lw=1, capsize=2, capthick=1),
           label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
           hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - DiagnosticReport')
ax.legend(
handleheight=2,     handlelength=3,     fontsize=6,
)

#plt.ylim(0, 0.1)

plt.savefig('retrieve-diagnostic-report.png', dpi=400)
plt.show()

# %%
x = ['Threshold 2 - Shares 3', 'Threshold 3 - Shares 5', 'Threshold 4 - Shares 7', 'Threshold 5 - Shares 9']

percentages = []

for key in encounter_keys:
    if '-s-' in key:
        percentage = key.split('-')[3]
        if percentage.isdigit():
            percentages.append(int(percentage))
        percentages.sort()
#percentages = [str(i) + '%' for i in percentages]
#percentages = [str(i) for i in percentages]
percentages = set(percentages)
percentages = sorted(list(percentages))
percentages = [str(i) for i in percentages]
percentages.append('norm')
percentages
# Out:
# ['10', '30', '40', '70', '80', '90', '100', 'norm']

# %%
split = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}
split_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

for percentage in percentages:
    for key in encounter_keys:
        if key.endswith('-' + percentage):
            if 't2n3' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t2n3]'.format(key))
                    split['t2n3'].append(mean_dict[key])
                    split_err['t2n3'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t2n3]'.format(key))
                    retrieve['t2n3'].append(mean_dict[key])
                    retrieve_err['t2n3'].append(conf_95_dict[key])
            elif 't3n5' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t3n5]'.format(key))
                    split['t3n5'].append(mean_dict[key])
                    split_err['t3n5'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t3n5]'.format(key))
                    retrieve['t3n5'].append(mean_dict[key])
                    retrieve_err['t3n5'].append(conf_95_dict[key])
            elif 't4n7' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t4n7]'.format(key))
                    split['t4n7'].append(mean_dict[key])
                    split_err['t4n7'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t4n7]'.format(key))
                    retrieve['t4n7'].append(mean_dict[key])
                    retrieve_err['t4n7'].append(conf_95_dict[key])
            elif 't5n9' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t5n9]'.format(key))
                    split['t5n9'].append(mean_dict[key])
                    split_err['t5n9'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t5n9]'.format(key))
                    retrieve['t5n9'].append(mean_dict[key])
                    retrieve_err['t5n9'].append(conf_95_dict[key])
# Out:
# appending key: t2n3-Encounter-r-10 to retrieve[t2n3]
# appending key: t2n3-Encounter-s-10 to split[t2n3]
# appending key: t3n5-Encounter-r-10 to retrieve[t3n5]
# appending key: t3n5-Encounter-s-10 to split[t3n5]
# appending key: t4n7-Encounter-r-10 to retrieve[t4n7]
# appending key: t4n7-Encounter-s-10 to split[t4n7]
# appending key: t5n9-Encounter-r-10 to retrieve[t5n9]
# appending key: t5n9-Encounter-s-10 to split[t5n9]
# appending key: t2n3-Encounter-r-30 to retrieve[t2n3]
# appending key: t2n3-Encounter-s-30 to split[t2n3]
# appending key: t3n5-Encounter-r-30 to retrieve[t3n5]
# appending key: t3n5-Encounter-s-30 to split[t3n5]
# appending key: t4n7-Encounter-r-30 to retrieve[t4n7]
# appending key: t4n7-Encounter-s-30 to split[t4n7]
# appending key: t5n9-Encounter-r-30 to retrieve[t5n9]
# appending key: t5n9-Encounter-s-30 to split[t5n9]
# appending key: t2n3-Encounter-s-40 to split[t2n3]
# appending key: t2n3-Encounter-r-40 to retrieve[t2n3]
# ...

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [split['t2n3'][i], split['t3n5'][i], split['t4n7'][i], split['t5n9'][i]],
            yerr=[split_err['t2n3'][i], split_err['t3n5'][i], split_err['t4n7'][i], split_err['t5n9'][i]],
           capsize=5,
           width=width,
           error_kw=dict(lw=1, capsize=2, capthick=1),
           label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
           hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - Encounter')
ax.legend(
handleheight=2,     handlelength=3,     fontsize=6,
)

#plt.ylim(0, 0.1)

plt.savefig('split-encounter.png', dpi=400)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [retrieve['t2n3'][i], retrieve['t3n5'][i], retrieve['t4n7'][i], retrieve['t5n9'][i]],
            yerr=[retrieve_err['t2n3'][i], retrieve_err['t3n5'][i], retrieve_err['t4n7'][i], retrieve_err['t5n9'][i]],
           capsize=5,
           width=width,
           error_kw=dict(lw=1, capsize=2, capthick=1),
           label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
           hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - Encounter')
ax.legend(
handleheight=2,     handlelength=3,     fontsize=6,
)

#plt.ylim(0, 0.1)

plt.savefig('retrieve-encounter.png', dpi=400)
plt.show()

# %%
x = ['Threshold 2 - Shares 3', 'Threshold 3 - Shares 5', 'Threshold 4 - Shares 7', 'Threshold 5 - Shares 9']

percentages = []

for key in condition_keys:
    if '-s-' in key:
        percentage = key.split('-')[3]
        if percentage.isdigit():
            percentages.append(int(percentage))
        percentages.sort()
#percentages = [str(i) + '%' for i in percentages]
#percentages = [str(i) for i in percentages]
percentages = set(percentages)
percentages = sorted(list(percentages))
percentages = [str(i) for i in percentages]
percentages.append('norm')
percentages
# Out:
# ['8', '16', '25', '33', '41', '75', '83', '91', '100', 'norm']

# %%
split = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}
split_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

retrieve_err = {
    't2n3': [],
    't3n5': [],
    't4n7': [],
    't5n9': []
}

for percentage in percentages:
    for key in condition_keys:
        if key.endswith('-' + percentage):
            if 't2n3' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t2n3]'.format(key))
                    split['t2n3'].append(mean_dict[key])
                    split_err['t2n3'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t2n3]'.format(key))
                    retrieve['t2n3'].append(mean_dict[key])
                    retrieve_err['t2n3'].append(conf_95_dict[key])
            elif 't3n5' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t3n5]'.format(key))
                    split['t3n5'].append(mean_dict[key])
                    split_err['t3n5'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t3n5]'.format(key))
                    retrieve['t3n5'].append(mean_dict[key])
                    retrieve_err['t3n5'].append(conf_95_dict[key])
            elif 't4n7' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t4n7]'.format(key))
                    split['t4n7'].append(mean_dict[key])
                    split_err['t4n7'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t4n7]'.format(key))
                    retrieve['t4n7'].append(mean_dict[key])
                    retrieve_err['t4n7'].append(conf_95_dict[key])
            elif 't5n9' in key:
                if '-s-' in key:
                    print('appending key: {} to split[t5n9]'.format(key))
                    split['t5n9'].append(mean_dict[key])
                    split_err['t5n9'].append(conf_95_dict[key])
                elif '-r-' in key:
                    print('appending key: {} to retrieve[t5n9]'.format(key))
                    retrieve['t5n9'].append(mean_dict[key])
                    retrieve_err['t5n9'].append(conf_95_dict[key])
# Out:
# appending key: t2n3-Condition-r-8 to retrieve[t2n3]
# appending key: t2n3-Condition-s-8 to split[t2n3]
# appending key: t3n5-Condition-r-8 to retrieve[t3n5]
# appending key: t3n5-Condition-s-8 to split[t3n5]
# appending key: t4n7-Condition-r-8 to retrieve[t4n7]
# appending key: t4n7-Condition-s-8 to split[t4n7]
# appending key: t5n9-Condition-r-8 to retrieve[t5n9]
# appending key: t5n9-Condition-s-8 to split[t5n9]
# appending key: t2n3-Condition-r-16 to retrieve[t2n3]
# appending key: t2n3-Condition-s-16 to split[t2n3]
# appending key: t3n5-Condition-r-16 to retrieve[t3n5]
# appending key: t3n5-Condition-s-16 to split[t3n5]
# appending key: t4n7-Condition-r-16 to retrieve[t4n7]
# appending key: t4n7-Condition-s-16 to split[t4n7]
# appending key: t5n9-Condition-r-16 to retrieve[t5n9]
# appending key: t5n9-Condition-s-16 to split[t5n9]
# appending key: t2n3-Condition-s-25 to split[t2n3]
# appending key: t2n3-Condition-r-25 to retrieve[t2n3]
# ...

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [split['t2n3'][i], split['t3n5'][i], split['t4n7'][i], split['t5n9'][i]],
            yerr=[split_err['t2n3'][i], split_err['t3n5'][i], split_err['t4n7'][i], split_err['t5n9'][i]],
           capsize=5,
           width=width,
           error_kw=dict(lw=1, capsize=2, capthick=1),
           label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
           hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Split - Condition')
ax.legend(
handleheight=2,     handlelength=3,     fontsize=6,
)

#plt.ylim(0, 0.1)

plt.savefig('split-condition.png', dpi=400)
plt.show()

# %%
positions = np.arange(len(x))

fig, ax = plt.subplots()

width = 0.05

for i, percentage in enumerate(percentages):
    offset = (i - len(percentages) / 2) * width
    ax.bar(positions + offset + width / 2,
           [retrieve['t2n3'][i], retrieve['t3n5'][i], retrieve['t4n7'][i], retrieve['t5n9'][i]],
            yerr=[retrieve_err['t2n3'][i], retrieve_err['t3n5'][i], retrieve_err['t4n7'][i], retrieve_err['t5n9'][i]],
           capsize=5,
           width=width,
           error_kw=dict(lw=1, capsize=2, capthick=1),
           label='Obfuscation {}%'.format(percentage) if percentage != 'norm' else 'Full encryption',
           hatch=hatch_patterns[i]
           )
ax.set_xticks(positions)
ax.set_xticklabels(x, fontsize=6)
ax.set_ylabel('Mean Execution Time (s)')
ax.set_title('Merge - Condition')
ax.legend(
    handleheight=2,
    handlelength=3,
    fontsize=6,
)

#plt.ylim(0, 0.1)

plt.savefig('retrieve-condition.png', dpi=400)
plt.show()
